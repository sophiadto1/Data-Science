# %% [markdown]
# <a href="https://colab.research.google.com/github/sophiadto1/Data-Science/blob/main/dela_Torre_Orosz_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stats Notebook Lab #4

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([12, 17, 18, 23, 56, 37, 48])

# %%
# population

# %%
def mean(x):
    return np.sum(x)/x.shape[0]

# %%
def var(x):
    return mean((x - mean(x))**2)

# %%
def std(x):
    return np.sqrt(var(x))

# %%
mean(x) #calculates mean
# Out:
# 30.142857142857142

# %%
var(x) #finds varience
# Out:
# 247.83673469387756

# %%
std(x) #finds standard deviation
# Out:
# 15.742831215949613

# %% [markdown]
# ### Random Number Generator

# %%
m = 75                 # multiplier
b = 74                 # increment
n = 65537              # modulus

# %%
x = 123456      # seed value

# %%
X = np.zeros(50000,) #

# %%
x = (m * x + b) % n

# %%
for i in range(X.shape[0]): #setting up function for graph

    x = (m * x + b) % n
    
    X[i] = x

X /= np.max(X)

# %%
plt.plot(X[:100],'.') #plots graph

# %%
plt.hist(X); #plots histogram

# %%
plt.hist(X,100); #plots histogram going by 100 on y-axis

# %%
X #creates array
# Out:
# array([0.23761349, 0.82162203, 0.62092012, ..., 0.97434958, 0.07512016,
#        0.63498894])

# %%
X
# Out:
# array([0.23761349, 0.82162203, 0.62092012, ..., 0.97434958, 0.07512016,
#        0.63498894])

# %%
X
# Out:
# array([0.23761349, 0.82162203, 0.62092012, ..., 0.97434958, 0.07512016,
#        0.63498894])

# %% [markdown]
# ### Random Numbers

# %%
X = np.random.random(50000,) #generates random numbers

# %%
plt.hist(X,100); #creates histogram

# %%
np.random.random() #generates random number
# Out:
# 0.07012700510618997

# %%
r = np.random.random()

# %%
r
# Out:
# 0.019802276756473614

# %%
r = np.random.randint(1,10) #generates random number between 1-10

# %%
r
# Out:
# 2

# %%
r = np.random.randint(1,10,size=(10,2)) #generates a pair of random numbers, with numbers 1-10

# %%
r
# Out:
# array([[2, 7],
#        [1, 9],
#        [4, 3],
#        [6, 4],
#        [3, 1],
#        [7, 8],
#        [8, 8],
#        [1, 9],
#        [1, 3],
#        [1, 8]])

# %%
np.random.seed(12345) #setting up function to create different types of graphs
data = np.random.randn(2, 100)

fig, axs = plt.subplots(2, 2, figsize=(10, 10))
axs[0, 0].hist(data[0])
axs[1, 0].scatter(data[0], data[1])
axs[0, 1].plot(data[0], data[1])
axs[1, 1].hist2d(data[0], data[1])

plt.show()

# %% [markdown]
# Normal Dist Data

# %%
mu = 100  # mean of distribution 
sigma = 15  # standard deviation of distribution
x = mu + sigma * np.random.randn(10000)

# %%
n,bins,patches = plt.hist(x) #creates histogram

# %%
bins
# Out:
# array([ 49.12615925,  59.76602668,  70.40589411,  81.04576154,
#         91.68562898, 102.32549641, 112.96536384, 123.60523127,
#        134.2450987 , 144.88496613, 155.52483356])

# %%
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(y) #plotting numbers to create graph

# %%
num_bins = 50
n,bins,patches = plt.hist(x, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)

# %%
def mean(x):
    return np.sum(x)/x.shape[0]

# %%
def var(x):
    return mean((x - mean(x))**2)

# %%
def std(x):
    return np.sqrt(var(x))

# %%
mean(x)
# Out:
# 100.01706493343725

# %%
std(x)
# Out:
# 15.033219789324425

# %% [markdown]
# # Normal Random Number Generator

# %%
#CDF PDF

# %% [markdown]
# ![alt text](https://wikimedia.org/api/rest_v1/media/math/render/svg/4abaca87a10ecfa77b5a205056523706fe6c9c3f)

# %%
def normal_pdf(x,mu,sigma):
  
  return (1/(np.sqrt(2*np.pi*sigma**2)))*np.exp((-(x-mu)**2)/(2*sigma**2))

# %%
x = np.linspace(-6,6,1000)

# %%
mu = 0

# %%
sigma = 1

# %%
pdf = normal_pdf(x,mu,sigma) #Use Normal for demo, replace with custom function pdf

# %%
plt.plot(x,pdf,'.')

# %%
def partial_sums(x):

  y = np.zeros(x.shape)
  
  for n in range(x.shape[0]):
    
    y[n] = np.sum(x[0:n])
    
  y = y / np.max(y)
    
  return y

# %%
cdf = partial_sums(pdf)

# %%
plt.plot(x,cdf,'.');

# %%
d_cdf = cdf[1:] - cdf[0:-1] #Demo to show that the diff of the cdf gives you back the pdf
plt.plot(x[1:],d_cdf,'.');  #Not required for sampling

# %%
plt.plot(cdf,x,'.');

# %%
def find_nearest(array, value):

  idx = np.argmin(np.abs(array - value))
  
  return idx

# %%
find_nearest(cdf, 0.1)
# Out:
# 393

# %%
x[393]
# Out:
# -1.2792792792792795

# %%
xr = np.random.random((10000,))

# %%
w = np.zeros(xr.shape[0])

for i in range(xr.shape[0]):
  
  w[i] = x[find_nearest(cdf, xr[i])]

# %%
w.shape
# Out:
# (10000,)

# %%
plt.hist(w,50);

# %%
num_bins = 50
n,bins,patches = plt.hist(w, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)

# %% [markdown]
# # Random Color

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
z = np.random.randint(0,255,size=(10,10,3))

# %%
plt.imshow(z) #importing image with different colors

# %%
z = np.zeros((10,10,3))

# %%
plt.imshow(z)

# %%
z = 0*np.ones((10,10,3))

# %%
plt.imshow(z)

# %%
z = 255*np.ones((10,10,3))

# %%
plt.imshow(z)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
z = np.ones((10,10,3)) 

z[:,:,0] = 1
z[:,:,1] = 0
z[:,:,2] = 0

plt.imshow(z)

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 1
z[:,:,2] = 0

plt.imshow(z)

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 0
z[:,:,2] = 1

plt.imshow(z)

# %%
z = np.ones((10,10,3))

r = np.random.rand()
g = np.random.rand()
b = np.random.rand()

print(r,g,b)

z[:,:,0] = r
z[:,:,1] = g
z[:,:,2] = b

plt.imshow(z);
# Out:
# 0.7300270065564927 0.7787808304844094 0.11177597446888776

# %%
for i in range(10):

    z = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()

    print(r,g,b)

    z[:,:,0] = r
    z[:,:,1] = g
    z[:,:,2] = b

    plt.imshow(z);
    plt.show()
# Out:
# 0.8138536111297549 0.1956993603674969 0.45314471421506963
# 0.8035250281957337 0.6061027069282953 0.8136673378323052
# 0.38276467207700693 0.3172566262585551 0.25182259284862485
# 0.25760675844280634 0.036804920182512135 0.5077846290459498
# 0.013329972777540222 0.03852965145885234 0.36498558547375515
# 0.33891346255448895 0.6384366125597362 0.8212519589395139
# 0.9762279205049945 0.9855034649546734 0.7084193305958214
# 0.8500397484438829 0.9286866965895959 0.2994421801074182
# 0.6316080564841641 0.5232797929880062 0.3052197477664478
# 0.1560070907293849 0.13595953727227894 0.19578442559747333

# %%
z1 = np.ones((10,10,3))
z1[:,:,0] = np.random.rand()
z1[:,:,1] = np.random.rand()
z1[:,:,2] = np.random.rand()

z2 = np.ones((10,10,3))
z2[:,:,0] = np.random.rand()
z2[:,:,1] = np.random.rand()
z2[:,:,2] = np.random.rand()

z3 = np.hstack((z1,z2))

plt.imshow(z3);
plt.show()

# %%
for i in range(10):
    
    z1 = np.ones((10,10,3))
    z1[:,:,0] = np.random.rand()
    z1[:,:,1] = np.random.rand()
    z1[:,:,2] = np.random.rand()

    z2 = np.ones((10,10,3))
    z2[:,:,0] = np.random.rand()
    z2[:,:,1] = np.random.rand()
    z2[:,:,2] = np.random.rand()

    z3 = np.hstack((z1,z2))

    plt.imshow(z3);
    plt.show()

# %%
for i in range(10):
    
    z1 = np.ones((10,10,3))
    z2 = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()

    z1[:,:,0] = r
    z1[:,:,1] = g
    z1[:,:,2] = b
    
    z2[:,:,0] = 1-r
    z2[:,:,1] = 1-g
    z2[:,:,2] = 1-b

    z3 = np.hstack((z1,z2))

    plt.imshow(z3);
    plt.show()

# %% [markdown]
# https://lospec.com/palette-list

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib
import imageio
from PIL import Image

def get_colors_lospec(url):
    im = imageio.imread(url)
    rgb_list = (im/255)[0,:,0:3]
    float_list = list(np.linspace(0,1,len(rgb_list)))    
    cdict = dict()
    for num, col in enumerate(['red', 'green', 'blue']):
        col_list = [[float_list[i], rgb_list[i][num], rgb_list[i][num]] for i in range(len(float_list))]
        cdict[col] = col_list
    cmp = mcolors.LinearSegmentedColormap('my_cmp', segmentdata=cdict, N=256)
    return cmp

# %%
url = 'https://lospec.com/palette-list/agb-32x.png'

# %%
url = 'https://lospec.com/palette-list/agb-1x.png'

# %%
url = 'https://lospec.com/palette-list/moondrom-1x.png'

# %%
im = imageio.imread(url)

# %%
plt.imshow(im);

# %%
z = np.random.randint(0,255,size=(10,10))

# %%
plt.imshow(z, cmap=get_colors_lospec(url))
plt.colorbar();

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sqrt(x**2 + y**2)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)*np.sin(3*x)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()
